# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
# Car_Name         301 non-null object
# Year             301 non-null int64
# Selling_Price    301 non-null float64
# Present_Price    301 non-null float64
# Kms_Driven       301 non-null int64
# Fuel_Type        301 non-null object
# Seller_Type      301 non-null object
# Transmission     301 non-null object
# Owner            301 non-null int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
print(df['Fuel_Type'].unique())
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_ds = df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_ds['Current_Year'] = 2021
final_ds.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2021
# 1       Manual      0          2021
# 2       Manual      0          2021
# 3       Manual      0          2021
# 4       Manual      0          2021

# %%
final_ds['No_Of_Yrs'] = final_ds['Current_Year'] - final_ds['Year']
final_ds.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  No_Of_Yrs
# 0       Manual      0          2021          7
# 1       Manual      0          2021          8
# 2       Manual      0          2021          4
# 3       Manual      0          2021         10
# 4       Manual      0          2021          7

# %%
final_ds.drop(['Year'],axis=1,inplace=True)

# %%
final_ds.drop(['Current_Year'],axis=1,inplace=True)

# %%
final_ds.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  No_Of_Yrs
# 0       Manual      0          7
# 1       Manual      0          8
# 2       Manual      0          4
# 3       Manual      0         10
# 4       Manual      0          7

# %%
final_ds = pd.get_dummies(final_ds,drop_first=True)

# %%
final_ds.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# No_Of_Yrs                   -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         No_Of_Yrs  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price           -0.236141          0.552339         -0.540571
# Present_Price            0.047584          0.473306         -0.465244
# Kms_Driven               0.524342          0.172515         -0.172874
# Owner                    0.182104         -0.053469          0.055687
# No_Of_Yrs                1.000000         -0.064315          0.059959
# Fuel_Type_Diesel        -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol         0.059959         -0.979648          1.000000
# Seller_Type_Individual   0.039896         -0.350467          0.358321
# Transmission_Manual     -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.124269            -0.050316
# No_Of_Yrs                             0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
sns.pairplot(final_ds)

# %%
corrmat = final_ds.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20)) #plot heat map
g = sns.heatmap(final_ds[top_corr_features].corr(),annot=True,cmap='RdYlGn')

# %%
x = final_ds.iloc[:,1:]
y = final_ds.iloc[:,0]

# %%
x.head()
# Out:
#    Present_Price  Kms_Driven  Owner  No_Of_Yrs  Fuel_Type_Diesel  \
# 0           5.59       27000      0          7                 0
# 1           9.54       43000      0          8                 1
# 2           9.85        6900      0          4                 0
# 3           4.15        5200      0         10                 0
# 4           6.87       42450      0          7                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
### Feature Importance

# from sklearn.ensemble import ExtraTreesRegressor
# model = ExtraTreesRegressor()
# model.fit(x,y)

# print(model.feature_importances_)

# #plot graph of feature importances for better visualization 
# feat_importances = pd.Series(model.feature_importances_, index=x.columns) 
# feat_importances.nlargest(5).plot(kind='barh') 
# plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (240, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random = RandomForestRegressor()

# %%
### HyperParameters
n_estimators = [int(x) for x in np.linspace(100,1200,num=12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
from sklearn.model_selection import RandomizedSearchCV#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'min_samples_leaf': [1, 2, 5, 10], 'max_features': ['auto', 'sqrt'], 'min_samples_split': [2, 5, 10, 15, 100], 'max_depth': [5, 10, 15, 20, 25, 30]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_leaf=5, max_features=sqrt, min_samples_split=5, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_leaf=5, max_features=sqrt, min_samples_split=5, max_depth=10, total=   2.3s
# [CV] n_estimators=900, min_samples_leaf=5, max_features=sqrt, min_samples_split=5, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_leaf=5, max_features=sqrt, min_samples_split=5, max_depth=10, total=   2.2s
# [CV] n_estimators=900, min_samples_leaf=5, max_features=sqrt, min_samples_split=5, max_depth=10
# [CV]  n_estimators=900, min_samples_leaf=5, max_features=sqrt, min_samples_split=5, max_depth=10, total=   2.6s
# [CV] n_estimators=900, min_samples_leaf=5, max_features=sqrt, min_samples_split=5, max_depth=10
# [CV]  n_estimators=900, min_samples_leaf=5, max_features=sqrt, min_samples_split=5, max_depth=10, total=   2.1s
# [CV] n_estimators=900, min_samples_leaf=5, max_features=sqrt, min_samples_split=5, max_depth=10
# [CV]  n_estimators=900, min_samples_leaf=5, max_features=sqrt, min_samples_split=5, max_depth=10, total=   2.5s
# [CV] n_estimators=1100, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=15
# [CV]  n_estimators=1100, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=15, total=   3.6s
# [CV] n_estimators=1100, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=15
# [CV]  n_estimators=1100, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=15, total=   5.2s
# [CV] n_estimators=1100, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=15
# [CV]  n_estimators=1100, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=15, total=   2.3s
# [CV] n_estimators=1100, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=15
# [CV]  n_estimators=1100, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=15, total=   3.2s
# [CV] n_estimators=1100, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=15
# [CV]  n_estimators=1100, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=15, total=   2.7s
# [CV] n_estimators=300, min_samples_leaf=5, max_features=auto, min_samples_split=100, max_depth=15
# [CV]  n_estimators=300, min_samples_leaf=5, max_features=auto, min_samples_split=100, max_depth=15, total=   0.9s
# [CV] n_estimators=300, min_samples_leaf=5, max_features=auto, min_samples_split=100, max_depth=15
# [CV]  n_estimators=300, min_samples_leaf=5, max_features=auto, min_samples_split=100, max_depth=15, total=   1.2s
# [CV] n_estimators=300, min_samples_leaf=5, max_features=auto, min_samples_split=100, max_depth=15
# [CV]  n_estimators=300, min_samples_leaf=5, max_features=auto, min_samples_split=100, max_depth=15, total=   1.2s
# [CV] n_estimators=300, min_samples_leaf=5, max_features=auto, min_samples_split=100, max_depth=15
# [CV]  n_estimators=300, min_samples_leaf=5, max_features=auto, min_samples_split=100, max_depth=15, total=   0.7s
# [CV] n_estimators=300, min_samples_leaf=5, max_features=auto, min_samples_split=100, max_depth=15
# [CV]  n_estimators=300, min_samples_leaf=5, max_features=auto, min_samples_split=100, max_depth=15, total=   0.8s
# [CV] n_estimators=400, min_samples_leaf=5, max_features=auto, min_samples_split=5, max_depth=15
# [CV]  n_estimators=400, min_samples_leaf=5, max_features=auto, min_samples_split=5, max_depth=15, total=   1.1s
# [CV] n_estimators=400, min_samples_leaf=5, max_features=auto, min_samples_split=5, max_depth=15
# [CV]  n_estimators=400, min_samples_leaf=5, max_features=auto, min_samples_split=5, max_depth=15, total=   1.2s
# [CV] n_estimators=400, min_samples_leaf=5, max_features=auto, min_samples_split=5, max_depth=15
# [CV]  n_estimators=400, min_samples_leaf=5, max_features=auto, min_samples_split=5, max_depth=15, total=   1.0s
# [CV] n_estimators=400, min_samples_leaf=5, max_features=auto, min_samples_split=5, max_depth=15
# [CV]  n_estimators=400, min_samples_leaf=5, max_features=auto, min_samples_split=5, max_depth=15, total=   1.3s
# [CV] n_estimators=400, min_samples_leaf=5, max_features=auto, min_samples_split=5, max_depth=15
# [CV]  n_estimators=400, min_samples_leaf=5, max_features=auto, min_samples_split=5, max_depth=15, total=   1.0s
# [CV] n_estimators=700, min_samples_leaf=10, max_features=auto, min_samples_split=5, max_depth=20
# [CV]  n_estimators=700, min_samples_leaf=10, max_features=auto, min_samples_split=5, max_depth=20, total=   1.8s
# [CV] n_estimators=700, min_samples_leaf=10, max_features=auto, min_samples_split=5, max_depth=20
# [CV]  n_estimators=700, min_samples_leaf=10, max_features=auto, min_samples_split=5, max_depth=20, total=   1.7s
# [CV] n_estimators=700, min_samples_leaf=10, max_features=auto, min_samples_split=5, max_depth=20
# [CV]  n_estimators=700, min_samples_leaf=10, max_features=auto, min_samples_split=5, max_depth=20, total=   1.9s
# [CV] n_estimators=700, min_samples_leaf=10, max_features=auto, min_samples_split=5, max_depth=20
# [CV]  n_estimators=700, min_samples_leaf=10, max_features=auto, min_samples_split=5, max_depth=20, total=   1.8s
# [CV] n_estimators=700, min_samples_leaf=10, max_features=auto, min_samples_split=5, max_depth=20
# [CV]  n_estimators=700, min_samples_leaf=10, max_features=auto, min_samples_split=5, max_depth=20, total=   1.7s
# [CV] n_estimators=1000, min_samples_leaf=1, max_features=sqrt, min_samples_split=2, max_depth=25
# [CV]  n_estimators=1000, min_samples_leaf=1, max_features=sqrt, min_samples_split=2, max_depth=25, total=   2.4s
# [CV] n_estimators=1000, min_samples_leaf=1, max_features=sqrt, min_samples_split=2, max_depth=25
# [CV]  n_estimators=1000, min_samples_leaf=1, max_features=sqrt, min_samples_split=2, max_depth=25, total=   2.5s
# [CV] n_estimators=1000, min_samples_leaf=1, max_features=sqrt, min_samples_split=2, max_depth=25
# [CV]  n_estimators=1000, min_samples_leaf=1, max_features=sqrt, min_samples_split=2, max_depth=25, total=   2.9s
# [CV] n_estimators=1000, min_samples_leaf=1, max_features=sqrt, min_samples_split=2, max_depth=25
# [CV]  n_estimators=1000, min_samples_leaf=1, max_features=sqrt, min_samples_split=2, max_depth=25, total=   4.1s
# [CV] n_estimators=1000, min_samples_leaf=1, max_features=sqrt, min_samples_split=2, max_depth=25
# [CV]  n_estimators=1000, min_samples_leaf=1, max_features=sqrt, min_samples_split=2, max_depth=25, total=   2.5s
# [CV] n_estimators=1100, min_samples_leaf=10, max_features=sqrt, min_samples_split=15, max_depth=5
# [CV]  n_estimators=1100, min_samples_leaf=10, max_features=sqrt, min_samples_split=15, max_depth=5, total=   2.5s
# [CV] n_estimators=1100, min_samples_leaf=10, max_features=sqrt, min_samples_split=15, max_depth=5
# [CV]  n_estimators=1100, min_samples_leaf=10, max_features=sqrt, min_samples_split=15, max_depth=5, total=   2.7s
# [CV] n_estimators=1100, min_samples_leaf=10, max_features=sqrt, min_samples_split=15, max_depth=5
# [CV]  n_estimators=1100, min_samples_leaf=10, max_features=sqrt, min_samples_split=15, max_depth=5, total=   2.7s
# [CV] n_estimators=1100, min_samples_leaf=10, max_features=sqrt, min_samples_split=15, max_depth=5
# [CV]  n_estimators=1100, min_samples_leaf=10, max_features=sqrt, min_samples_split=15, max_depth=5, total=   2.6s
# [CV] n_estimators=1100, min_samples_leaf=10, max_features=sqrt, min_samples_split=15, max_depth=5
# [CV]  n_estimators=1100, min_samples_leaf=10, max_features=sqrt, min_samples_split=15, max_depth=5, total=   3.0s
# [CV] n_estimators=300, min_samples_leaf=1, max_features=sqrt, min_samples_split=15, max_depth=15
# [CV]  n_estimators=300, min_samples_leaf=1, max_features=sqrt, min_samples_split=15, max_depth=15, total=   0.6s
# [CV] n_estimators=300, min_samples_leaf=1, max_features=sqrt, min_samples_split=15, max_depth=15
# [CV]  n_estimators=300, min_samples_leaf=1, max_features=sqrt, min_samples_split=15, max_depth=15, total=   1.1s
# [CV] n_estimators=300, min_samples_leaf=1, max_features=sqrt, min_samples_split=15, max_depth=15
# [CV]  n_estimators=300, min_samples_leaf=1, max_features=sqrt, min_samples_split=15, max_depth=15, total=   0.9s
# [CV] n_estimators=300, min_samples_leaf=1, max_features=sqrt, min_samples_split=15, max_depth=15
# [CV]  n_estimators=300, min_samples_leaf=1, max_features=sqrt, min_samples_split=15, max_depth=15, total=   0.9s
# [CV] n_estimators=300, min_samples_leaf=1, max_features=sqrt, min_samples_split=15, max_depth=15
# [CV]  n_estimators=300, min_samples_leaf=1, max_features=sqrt, min_samples_split=15, max_depth=15, total=   1.2s
# [CV] n_estimators=700, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=5
# [CV]  n_estimators=700, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=5, total=   2.1s
# [CV] n_estimators=700, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=5
# [CV]  n_estimators=700, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=5, total=   2.4s
# [CV] n_estimators=700, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=5
# [CV]  n_estimators=700, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=5, total=   2.8s
# [CV] n_estimators=700, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=5
# [CV]  n_estimators=700, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=5, total=   1.7s
# [CV] n_estimators=700, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=5
# [CV]  n_estimators=700, min_samples_leaf=2, max_features=sqrt, min_samples_split=10, max_depth=5, total=   1.9s
# [CV] n_estimators=700, min_samples_leaf=1, max_features=auto, min_samples_split=15, max_depth=20
# [CV]  n_estimators=700, min_samples_leaf=1, max_features=auto, min_samples_split=15, max_depth=20, total=   1.7s
# [CV] n_estimators=700, min_samples_leaf=1, max_features=auto, min_samples_split=15, max_depth=20
# [CV]  n_estimators=700, min_samples_leaf=1, max_features=auto, min_samples_split=15, max_depth=20, total=   2.7s
# [CV] n_estimators=700, min_samples_leaf=1, max_features=auto, min_samples_split=15, max_depth=20
# [CV]  n_estimators=700, min_samples_leaf=1, max_features=auto, min_samples_split=15, max_depth=20, total=   2.0s
# [CV] n_estimators=700, min_samples_leaf=1, max_features=auto, min_samples_split=15, max_depth=20
# [CV]  n_estimators=700, min_samples_leaf=1, max_features=auto, min_samples_split=15, max_depth=20, total=   2.0s
# [CV] n_estimators=700, min_samples_leaf=1, max_features=auto, min_samples_split=15, max_depth=20
# [CV]  n_estimators=700, min_samples_leaf=1, max_features=auto, min_samples_split=15, max_depth=20, total=   2.0s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  1.7min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oob_score=Fals...
#                    iid='deprecated', n_iter=10, n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
predictions=rf_random.predict(x_test)
predictions
# Out:
# array([ 7.03198581,  0.52245504,  4.94714766,  8.39186811, 12.41514983,
#         5.28535051,  3.30678518,  0.42814407,  3.87023384,  5.07885339,
#         2.83869445,  0.65398604,  5.12387857,  7.2585903 ,  7.45316796,
#        12.75015075,  6.99480666,  4.17689924,  0.48810271,  1.32173493,
#         3.25058301,  5.22511044,  5.42587967, 10.40560428,  0.23633181,
#         0.68292694,  0.3238466 ,  0.70295621,  0.51777002,  4.86352769,
#         2.86466526,  5.83298587,  0.52455088,  7.14402482,  3.30181866,
#         1.15240841,  5.75361481,  5.47894233,  0.25026506,  7.50049271,
#         7.59857841, 22.16623364,  5.09947806,  4.53372472,  5.57473626,
#        10.32075664,  0.25266109,  0.76262127,  5.43908871,  6.78489682,
#         6.62160033,  2.98618646,  5.3764417 , 22.16623364,  1.15240841,
#         1.15261226,  0.40724836,  2.75458658,  3.61485075,  2.52872021,
#         4.55912661])

# %%
sns.distplot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.7131506213358756
# MSE: 1.891162902776681
# RMSE: 1.3751955870990429

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest_regression_model.pkl', 'wb')

# dump information to that file
pickle.dump(rf_random, file)
